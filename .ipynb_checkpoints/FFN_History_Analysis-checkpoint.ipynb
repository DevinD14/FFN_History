# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import re
# Out:
# C:\Users\devin\AppData\Local\Temp\ipykernel_14708\368733898.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## Import and Clean Data

# %%
data = pd.read_excel('data/FFN_History_data.xlsx')

# %%
data.dropna(subset=['Name'], inplace=True)
data.reset_index(drop=True, inplace=True)

# %%
data

# %% [markdown]
# ## Compute Total Number of Participants in Each Contest

# %%
# Calculate the total number of unique participants in each league per year
total_players = data.groupby(['League', 'Year'])['ID'].nunique().reset_index(name='Total Players')

# Merge the total_players with the original dataframe to add the Total Players column
data_merged = pd.merge(data, total_players, how='left', on=['League', 'Year'])

data_merged.tail()
# Out:
#       ID     Name                League  Year  League Year #  Rank     Sport  \
# 926  172  Charles  FFN CFF Bestball FBS  2024              1   4.0  Football
# 927  155     Trey  FFN CFF Bestball FBS  2024              1   5.0  Football
# 928  123    Nakul  FFN CFF Bestball FBS  2024              1   6.0  Football
# 929  173   Daniel  FFN CFF Bestball FBS  2024              1   7.0  Football
# 930  114     Jack  FFN CFF Bestball FBS  2024              1   8.0  Football
#
#      Minigame?  Dynasty?  Bestball?  Orphaned?  Total Players
# 926          0         0          1          0              8
# 927          0         0          1          0              8
# 928          0         0          1          0              8
# 929          0         0          1          0              8
# 930          0         0          1          0              8

# %%
# Update the Data DataFrame to reflect the total players results
data['Total Players'] = data_merged['Total Players']

# Find the largest Rank in each league-year combination
largest_rank = data.groupby(['League', 'Year'])['Rank'].max().reset_index(name='Largest Rank')

# Merge this back with the original DataFrame
data_with_largest_rank = pd.merge(data, largest_rank, how='left', on=['League', 'Year'])

# Update the 'Total Players' column based on the largest rank exceeding the current total players value
data_with_largest_rank['Total Players'] = data_with_largest_rank.apply(
    lambda row: max(row['Total Players'], row['Largest Rank']), axis=1
)

# Dropping the 'Largest Rank' column as it's no longer needed
data_with_largest_rank.drop(columns=['Largest Rank'], inplace=True)

data_with_largest_rank.tail()  # Displaying the last few rows to verify the update
# Out:
#       ID     Name                League  Year  League Year #  Rank     Sport  \
# 926  172  Charles  FFN CFF Bestball FBS  2024              1   4.0  Football
# 927  155     Trey  FFN CFF Bestball FBS  2024              1   5.0  Football
# 928  123    Nakul  FFN CFF Bestball FBS  2024              1   6.0  Football
# 929  173   Daniel  FFN CFF Bestball FBS  2024              1   7.0  Football
# 930  114     Jack  FFN CFF Bestball FBS  2024              1   8.0  Football
#
#      Minigame?  Dynasty?  Bestball?  Orphaned?  Total Players
# 926          0         0          1          0            8.0
# 927          0         0          1          0            8.0
# 928          0         0          1          0            8.0
# 929          0         0          1          0            8.0
# 930          0         0          1          0            8.0

# %%
# Update the Data DataFrame to reflect the total players results
data['Total Players'] = data_with_largest_rank['Total Players']

# %%
data
# Out:
#       ID         Name                      League  Year  League Year #  Rank  \
# 0    112        Grant                  FFN Alumni  2021              1   1.0
# 1    109          Ari                  FFN Alumni  2021              1   2.0
# 2    103          Cam                  FFN Alumni  2021              1   3.0
# 3    106         Kyle                  FFN Alumni  2021              1   4.0
# 4    127         DMac                  FFN Alumni  2021              1   5.0
# 5    125         Soup                  FFN Alumni  2021              1   6.0
# 6    105       Graham                  FFN Alumni  2021              1   7.0
# 7    101          Ben                  FFN Alumni  2021              1   8.0
# 8    102        Devin                  FFN Alumni  2021              1   9.0
# 9    116         Jude                  FFN Alumni  2021              1  10.0
# 10   107         Zack                  FFN Alumni  2021              1  11.0
# 11   104       Double                  FFN Alumni  2021              1  12.0
# 12   106         Kyle                  FFN Alumni  2022              2   1.0
# 13   112        Grant                  FFN Alumni  2022              2   2.0
# 14   109          Ari                  FFN Alumni  2022              2   3.0
# 15   103          Cam                  FFN Alumni  2022              2   4.0
# 16   104       Double                  FFN Alumni  2022              2   5.0
# 17   102        Devin                  FFN Alumni  2022              2   6.0
# 18   125         Soup                  FFN Alumni  2022              2   7.0
# 19   105       Graham                  FFN Alumni  2022              2   8.0
# 20   107         Zack                  FFN Alumni  2022              2   9.0
# 21   116         Jude                  FFN Alumni  2022              2  10.0
# 22   127         DMac                  FFN Alumni  2022              2  11.0
# 23   101          Ben                  FFN Alumni  2022              2  12.0
# 24   106         Kyle                  FFN Alumni  2023              3   1.0
# 25   104       Double                  FFN Alumni  2023              3   2.0
# 26   103          Cam                  FFN Alumni  2023              3   3.0
# 27   102        Devin                  FFN Alumni  2023              3   4.0
# 28   109          Ari                  FFN Alumni  2023              3   5.0
# 29   112        Grant                  FFN Alumni  2023              3   6.0
# 30   127         DMac                  FFN Alumni  2023              3   7.0
# 31   105       Graham                  FFN Alumni  2023              3   8.0
# 32   107         Zack                  FFN Alumni  2023              3   9.0
# 33   116         Jude                  FFN Alumni  2023              3  10.0
# 34   101          Ben                  FFN Alumni  2023              3  11.0
# 35   125         Soup                  FFN Alumni  2023              3  12.0
# 36   127         DMac                  FFN Alumni  2024              4   1.0
# 37   105       Graham                  FFN Alumni  2024              4   2.0
# 38   102        Devin                  FFN Alumni  2024              4   3.0
# 39   104       Double                  FFN Alumni  2024              4   4.0
# 40   109          Ari                  FFN Alumni  2024              4   5.0
# 41   125         Soup                  FFN Alumni  2024              4   6.0
# 42   112        Grant                  FFN Alumni  2024              4   7.0
# 43   116         Jude                  FFN Alumni  2024              4   8.0
# 44   103          Cam                  FFN Alumni  2024              4   9.0
# 45   107         Zack                  FFN Alumni  2024              4  10.0
# 46   101          Ben                  FFN Alumni  2024              4  11.0
# 47   106         Kyle                  FFN Alumni  2024              4  12.0
# 48   145      Matthew                  Multiverse  2022              1   1.0
# 49   104       Double                  Multiverse  2022              1   2.0
# 50   141      Anthony                  Multiverse  2022              1   3.0
# 51   114         Jack                  Multiverse  2022              1   4.0
# 52   112        Grant                  Multiverse  2022              1   5.0
# 53   146       Thomas                  Multiverse  2022              1   6.0
# 54   143       Andrew                  Multiverse  2022              1   7.0
# 55   144      Brandon                  Multiverse  2022              1   8.0
# 56   142        Dante                  Multiverse  2022              1   9.0
# 57   109          Ari                  Multiverse  2022              1  10.0
# 58   106         Kyle                  Multiverse  2022              1  11.0
# 59   102        Devin                  Multiverse  2022              1  12.0
# 60   142        Dante                  Multiverse  2023              2   1.0
# 61   104       Double                  Multiverse  2023              2   2.0
# 62   106         Kyle                  Multiverse  2023              2   3.0
# 178  155         Trey                  Multisport  2022              1   5.0
# 179  156       Landon                  Multisport  2022              1   6.0
# 180  124        Mitch                  Multisport  2022              1   7.0
# 181  164         Noah                  Multisport  2022              1   8.0
# 182  163         Josh                  Multisport  2022              1   9.0
# 183  114         Jack                  Multisport  2022              1  10.0
# 184  162         Chad                  Multisport  2023              2   1.0
# 185  102        Devin                  Multisport  2023              2   2.0
# 186  163         Josh                  Multisport  2023              2   3.0
# 187  156       Landon                  Multisport  2023              2   4.0
# 188  105       Graham                  Multisport  2023              2   5.0
# 189  160      Tristan                  Multisport  2023              2   6.0
# 190  155         Trey                  Multisport  2023              2   7.0
# 191  124        Mitch                  Multisport  2023              2   8.0
# 192  164         Noah                  Multisport  2023              2   9.0
# 193  114         Jack                  Multisport  2023              2  10.0
# 194  162         Chad                  Multisport  2024              3   1.0
# 195  102        Devin                  Multisport  2024              3   2.0
# 196  156       Landon                  Multisport  2024              3   3.0
# 197  124        Mitch                  Multisport  2024              3   4.0
# 198  163         Josh                  Multisport  2024              3   5.0
# 199  160      Tristan                  Multisport  2024              3   6.0
# 200  105       Graham                  Multisport  2024              3   7.0
# 201  155         Trey                  Multisport  2024              3   8.0
# 202  114         Jack                  Multisport  2024              3   9.0
# 203  164         Noah                  Multisport  2024              3  10.0
# 204  102        Devin                  Multisport  2022              1   1.0
# 205  162         Chad                  Multisport  2022              1   2.0
# 206  164         Noah                  Multisport  2022              1   3.0
# 207  105       Graham                  Multisport  2022              1   4.0
# 208  155         Trey                  Multisport  2022              1   5.0
# 209  156       Landon                  Multisport  2022              1   6.0
# 210  160      Tristan                  Multisport  2022              1   7.0
# 211  163         Josh                  Multisport  2022              1   8.0
# 212  114         Jack                  Multisport  2022              1   9.0
# 213  124        Mitch                  Multisport  2022              1  10.0
# 214  102        Devin                  Multisport  2023              2   1.0
# 215  164         Noah                  Multisport  2023              2   2.0
# 216  162         Chad                  Multisport  2023              2   3.0
# 217  105       Graham                  Multisport  2023              2   4.0
# 218  163         Josh                  Multisport  2023              2   5.0
# 219  156       Landon                  Multisport  2023              2   6.0
# 220  160      Tristan                  Multisport  2023              2   7.0
# 221  155         Trey                  Multisport  2023              2   8.0
# 222  124        Mitch                  Multisport  2023              2   9.0
# 223  114         Jack                  Multisport  2023              2  10.0
# 224  105       Graham                  Multisport  2024              3   1.0
# 225  102        Devin                  Multisport  2024              3   2.0
# 226  162         Chad                  Multisport  2024              3   3.0
# 227  164         Noah                  Multisport  2024              3   4.0
# 228  160      Tristan                  Multisport  2024              3   5.0
# 229  155         Trey                  Multisport  2024              3   6.0
# 230  163         Josh                  Multisport  2024              3   7.0
# 231  124        Mitch                  Multisport  2024              3   8.0
# 232  114         Jack                  Multisport  2024              3   9.0
# 233  156       Landon                  Multisport  2024              3  10.0
# 234  156       Landon                  Multisport  2023              1   1.0
# 235  164         Noah                  Multisport  2023              1   2.0
# 236  124        Mitch                  Multisport  2023              1   3.0
# 237  102        Devin                  Multisport  2023              1   4.0
# 238  162         Chad                  Multisport  2023              1   5.0
# 239  105       Graham                  Multisport  2023              1   6.0
# 240  114         Jack                  Multisport  2023              1   7.0
# 241  155         Trey                  Multisport  2023              1   8.0
# 242  160      Tristan                  Multisport  2023              1   9.0
# 243  163         Josh                  Multisport  2023              1  10.0
# 244  102        Devin                  Multisport  2024              2   1.0
# 245  124        Mitch                  Multisport  2024              2   2.0
# 246  105       Graham                  Multisport  2024              2   3.0
# 247  160      Tristan                  Multisport  2024              2   4.0
# 248  114         Jack                  Multisport  2024              2   5.0
# 249  156       Landon                  Multisport  2024              2   6.0
# 250  163         Josh                  Multisport  2024              2   7.0
# 251  162         Chad                  Multisport  2024              2   8.0
# 252  164         Noah                  Multisport  2024              2   9.0
# 253  155         Trey                  Multisport  2024              2  10.0
# 254  124        Mitch                  Multisport  2025              3   1.0
# 255  102        Devin                  Multisport  2025              3   2.0
# 256  114         Jack                  Multisport  2025              3   3.0
# 257  105       Graham                  Multisport  2025              3   4.0
# 258  162         Chad                  Multisport  2025              3   5.0
# 259  164         Noah                  Multisport  2025              3   6.0
# 260  156       Landon                  Multisport  2025              3   7.0
# 261  155         Trey                  Multisport  2025              3   8.0
# 262  163         Josh                  Multisport  2025              3   9.0
# 263  160      Tristan                  Multisport  2025              3  10.0
# 264  104       Double                     dyNASTY  2023              1   1.0
# 265  174      Broseph                     dyNASTY  2023              1   2.0
# 266  105       Graham                     dyNASTY  2023              1   3.0
# 267  169       Deaven                     dyNASTY  2023              1   4.0
# 268  100      Fantasy                     dyNASTY  2023              1   5.0
# 269  168         Dave                     dyNASTY  2023              1   6.0
# 270  106         Kyle                     dyNASTY  2023              1   7.0
# 271  109          Ari                     dyNASTY  2023              1   8.0
# 272  159        Quinn                     dyNASTY  2023              1   9.0
# 273  124        Mitch                     dyNASTY  2023              1  10.0
# 274  114         Jack                     dyNASTY  2023              1  11.0
# 275  102        Devin                     dyNASTY  2023              1  12.0
# 276  159        Quinn                     dyNASTY  2024              2   1.0
# 277  100      Fantasy                     dyNASTY  2024              2   2.0
# 278  174      Broseph                     dyNASTY  2024              2   3.0
# 279  169       Deaven                     dyNASTY  2024              2   4.0
# 280  109          Ari                     dyNASTY  2024              2   5.0
# 281  106         Kyle                     dyNASTY  2024              2   6.0
# 282  105       Graham                     dyNASTY  2024              2   7.0
# 283  102        Devin                     dyNASTY  2024              2   8.0
# 284  104       Double                     dyNASTY  2024              2   9.0
# 285  114         Jack                     dyNASTY  2024              2  10.0
# 286  124        Mitch                     dyNASTY  2024              2  11.0
# 287  168         Dave                     dyNASTY  2024              2  12.0
# 288  162         Chad            Bestball Dynasty  2023              1   1.0
# 289  152         John            Bestball Dynasty  2023              1   2.0
# 290  163         Josh            Bestball Dynasty  2023              1   3.5
# 291  150         Joel            Bestball Dynasty  2023              1   3.5
# 292  124        Mitch            Bestball Dynasty  2023              1   5.5
# 293  166       Josh S            Bestball Dynasty  2023              1   5.5
# 294  104       Double            Bestball Dynasty  2023              1   7.0
# 295  102        Devin            Bestball Dynasty  2023              1   8.0
# 296  167       Steven            Bestball Dynasty  2023              1   9.0
# 297  114         Jack            Bestball Dynasty  2023              1  10.0
# 298  106         Kyle            Bestball Dynasty  2023              1  11.0
# 299  164         Noah            Bestball Dynasty  2023              1  12.0
# 300  167       Steven            Bestball Dynasty  2024              2   1.0
# 301  124        Mitch            Bestball Dynasty  2024              2   2.0
# 302  102        Devin            Bestball Dynasty  2024              2   3.5
# 303  104       Double            Bestball Dynasty  2024              2   3.5
# 304  162         Chad            Bestball Dynasty  2024              2   5.5
# 305  166       Josh S            Bestball Dynasty  2024              2   5.5
# 306  163         Josh            Bestball Dynasty  2024              2   7.0
# 307  164         Noah            Bestball Dynasty  2024              2   8.0
# 308  106         Kyle            Bestball Dynasty  2024              2   9.0
# 309  150         Joel            Bestball Dynasty  2024              2  10.0
# 310  152         John            Bestball Dynasty  2024              2  11.0
# 311  114         Jack            Bestball Dynasty  2024              2  12.0
# 312  105       Graham            FFN Invitational  2023             10   1.0
# 313  124        Mitch            FFN Invitational  2023             10   2.0
# 314  106         Kyle            FFN Invitational  2023             10   3.0
# 315  113        Davis            FFN Invitational  2023             10   4.0
# 316  104       Double            FFN Invitational  2023             10   5.0
# 317  123        Nakul            FFN Invitational  2023             10   6.0
# 318  159        Quinn            FFN Invitational  2023             10   7.0
# 319  103          Cam            FFN Invitational  2023             10   8.0
# 320  102        Devin            FFN Invitational  2023             10   9.0
# 321  125         Soup            FFN Invitational  2023             10  10.0
# 322  114         Jack            FFN Invitational  2023             10  11.0
# 323  109          Ari            FFN Invitational  2023             10  12.0
# 324  123        Nakul            FFN Invitational  2024             11   1.0
# 325  124        Mitch            FFN Invitational  2024             11   2.0
# 326  106         Kyle            FFN Invitational  2024             11   3.0
# 327  105       Graham            FFN Invitational  2024             11   4.0
# 328  102        Devin            FFN Invitational  2024             11   5.0
# 329  114         Jack            FFN Invitational  2024             11   6.0
# 330  103          Cam            FFN Invitational  2024             11   7.0
# 331  159        Quinn            FFN Invitational  2024             11   8.0
# 332  109          Ari            FFN Invitational  2024             11   9.0
# 333  104       Double            FFN Invitational  2024             11  10.0
# 334  125         Soup            FFN Invitational  2024             11  11.0
# 335  113        Davis            FFN Invitational  2024             11  12.0
# 336  105       Graham        NFL Playoffs Fantasy  2023              1   1.0
# 337  109          Ari        NFL Playoffs Fantasy  2023              1   2.0
# 338  106         Kyle        NFL Playoffs Fantasy  2023              1   3.0
# 339  104       Double        NFL Playoffs Fantasy  2023              1   4.0
# 340  159        Quinn        NFL Playoffs Fantasy  2023              1   5.0
# 341  102        Devin        NFL Playoffs Fantasy  2023              1   6.0
# 342  114         Jack        NFL Playoffs Fantasy  2023              1   7.0
# 343  124        Mitch        NFL Playoffs Fantasy  2023              1   8.0
# 344  123        Nakul        NFL Playoffs Fantasy  2024              2   1.0
# 345  124        Mitch        NFL Playoffs Fantasy  2024              2   2.0
# 346  105       Graham        NFL Playoffs Fantasy  2024              2   3.0
# 347  106         Kyle        NFL Playoffs Fantasy  2024              2   4.0
# 348  114         Jack        NFL Playoffs Fantasy  2024              2   5.0
# 349  104       Double        NFL Playoffs Fantasy  2024              2   6.0
# 350  159        Quinn        NFL Playoffs Fantasy  2024              2   7.0
# 351  102        Devin        NFL Playoffs Fantasy  2024              2   8.0
# 352  105       Graham               March Sadness  2023              2   1.0
# 353  123        Nakul               March Sadness  2023              2   2.0
# 354  113        Davis               March Sadness  2023              2   3.0
# 355  102        Devin               March Sadness  2023              2   4.0
# 356  104       Double               March Sadness  2023              2   5.0
# 357  124        Mitch               March Sadness  2023              2   6.0
# 358  122     Nicholas               March Sadness  2023              2   7.0
# 359  106         Kyle               March Sadness  2023              2   8.0
# 360  114         Jack               March Sadness  2023              2   9.0
# 361  121       Falcon               March Sadness  2022              1   1.0
# 362  104       Double               March Sadness  2022              1   2.0
# 363  106         Kyle               March Sadness  2022              1   3.0
# 364  102        Devin               March Sadness  2022              1   4.0
# 365  101          Ben               March Sadness  2022              1   5.0
# 366  105       Graham               March Sadness  2022              1   6.0
# 367  113        Davis               March Sadness  2022              1   7.0
# 368  114         Jack               March Sadness  2022              1   8.0
# 369  105       Graham               March Sadness  2024              3   1.0
# 370  102        Devin               March Sadness  2024              3   2.0
# 371  124        Mitch               March Sadness  2024              3   3.0
# 372  123        Nakul               March Sadness  2024              3   4.0
# 373  114         Jack               March Sadness  2024              3   5.0
# 374  113        Davis               March Sadness  2024              3   6.0
# 375  106         Kyle               March Sadness  2024              3   7.0
# 376  159        Quinn               March Sadness  2024              3   8.0
# 377  104       Double               March Sadness  2024              3   9.0
# 378  106         Kyle               March Sadness  2025              4   1.0
# 379  124        Mitch               March Sadness  2025              4   2.0
# 380  114         Jack               March Sadness  2025              4   3.0
# 381  123        Nakul               March Sadness  2025              4   4.0
# 382  113        Davis               March Sadness  2025              4   5.0
# 383  105       Graham               March Sadness  2025              4   6.0
# 384  104       Double               March Sadness  2025              4   7.0
# 385  102        Devin               March Sadness  2025              4   8.0
# 386  159        Quinn               March Sadness  2025              4   9.0
# 387  102        Devin                Puck Redraft  2023              1   1.0
# 388  162         Chad                Puck Redraft  2023              1   2.0
# 389  109          Ari                Puck Redraft  2023              1   3.0
# 390  172      Charles                Puck Redraft  2023              1   4.0
# 391  161            J                Puck Redraft  2023              1   5.0
# 392  105       Graham                Puck Redraft  2023              1   6.0
# 393  114         Jack                Puck Redraft  2023              1   7.0
# 394  173       Daniel                Puck Redraft  2023              1   8.0
# 395  164         Noah                Puck Redraft  2023              1   9.0
# 396  104       Double                Puck Redraft  2023              1  10.0
# 397  102        Devin                Puck Redraft  2024              2   1.0
# 398  105       Graham                Puck Redraft  2024              2   2.0
# 399  173       Daniel                Puck Redraft  2024              2   3.0
# 400  183       Kelsey                Puck Redraft  2024              2   4.0
# 401  175  Ben Shelton                Puck Redraft  2024              2   5.0
# 402  176     Landon K                Puck Redraft  2024              2   6.0
# 403  177         Cory                Puck Redraft  2024              2   7.0
# 404  172      Charles                Puck Redraft  2024              2   8.0
# 405  173       Daniel                Puck Redraft  2025              3   1.0
# 406  105       Graham                Puck Redraft  2025              3   2.0
# 407  102        Devin                Puck Redraft  2025              3   3.0
# 408  183       Kelsey                Puck Redraft  2025              3   4.0
# 409  164         Noah                Puck Redraft  2025              3   5.0
# 410  175  Ben Shelton                Puck Redraft  2025              3   6.0
# 411  172      Charles                Puck Redraft  2025              3   7.0
# 412  185  Justin Hill                Puck Redraft  2025              3   8.0
# 413  109          Ari              NBA FFN Alumni  2022              1   1.0
# 414  121       Falcon              NBA FFN Alumni  2022              1   2.0
# 415  102        Devin              NBA FFN Alumni  2022              1   3.0
# 416  104       Double              NBA FFN Alumni  2022              1   4.0
# 417  117    1st Quinn              NBA FFN Alumni  2022              1   5.0
# 418  105       Graham              NBA FFN Alumni  2022              1   6.0
# 419  112        Grant              NBA FFN Alumni  2022              1   7.0
# 420  114         Jack              NBA FFN Alumni  2022              1   8.0
# 421  106         Kyle              NBA FFN Alumni  2022              1   9.0
# 422  101          Ben              NBA FFN Alumni  2022              1  10.0
# 423  102        Devin        NBA Playoffs Fantasy  2023              1   1.0
# 424  104       Double        NBA Playoffs Fantasy  2023              1   2.0
# 425  122     Nicholas        NBA Playoffs Fantasy  2023              1   3.0
# 426  105       Graham        NBA Playoffs Fantasy  2023              1   4.0
# 427  162         Chad        NBA Playoffs Fantasy  2023              1   5.0
# 428  124        Mitch        NBA Playoffs Fantasy  2023              1   6.0
# 429  113        Davis        NBA Playoffs Fantasy  2023              1   7.0
# 430  114         Jack        NBA Playoffs Fantasy  2023              1   8.0
# 431  105       Graham        NBA Playoffs Fantasy  2024              2   1.0
# 432  159        Quinn        NBA Playoffs Fantasy  2024              2   2.0
# 433  106         Kyle        NBA Playoffs Fantasy  2024              2   3.0
# 434  123        Nakul        NBA Playoffs Fantasy  2024              2   4.0
# 435  104       Double        NBA Playoffs Fantasy  2024              2   5.0
# 436  102        Devin        NBA Playoffs Fantasy  2024              2   6.0
# 437  124        Mitch        NBA Playoffs Fantasy  2024              2   7.0
# 438  114         Jack        NBA Playoffs Fantasy  2024              2   8.0
# 439  124        Mitch        NBA Playoffs Fantasy  2025              3   1.0
# 440  105       Graham        NBA Playoffs Fantasy  2025              3   2.0
# 441  102        Devin        NBA Playoffs Fantasy  2025              3   3.0
# 442  114         Jack        NBA Playoffs Fantasy  2025              3   4.0
# 443  106         Kyle        NBA Playoffs Fantasy  2025              3   5.0
# 444  104       Double        NBA Playoffs Fantasy  2025              3   6.0
# 445  159        Quinn        NBA Playoffs Fantasy  2025              3   7.0
# 446  123        Nakul        NBA Playoffs Fantasy  2025              3   8.0
# 447  102        Devin        NFL Predict the Pick  2023              1   1.0
# 448  114         Jack        NFL Predict the Pick  2023              1   2.0
# 449  106         Kyle        NFL Predict the Pick  2023              1   3.0
# 450  104       Double        NFL Predict the Pick  2023              1   4.0
# 451  124        Mitch        NFL Predict the Pick  2023              1   5.0
# 452  163         Josh        NFL Predict the Pick  2023              1   6.0
# 453  162         Chad        NFL Predict the Pick  2023              1   7.0
# 454  105       Graham        NFL Predict the Pick  2023              1   8.0
# 455  109          Ari        NFL Predict the Pick  2023              1   9.0
# 456  164         Noah        NFL Predict the Pick  2023              1  10.0
# 457  122     Nicholas        NFL Predict the Pick  2023              1  11.0
# 458  123        Nakul        NFL Predict the Pick  2023              1  12.0
# 459  114         Jack        NFL Predict the Pick  2024              2   1.0
# 460  102        Devin        NFL Predict the Pick  2024              2   2.0
# 461  164         Noah        NFL Predict the Pick  2024              2   3.0
# 462  163         Josh        NFL Predict the Pick  2024              2   4.0
# 463  105       Graham        NFL Predict the Pick  2024              2   5.0
# 464  124        Mitch        NFL Predict the Pick  2024              2   6.0
# 465  123        Nakul        NFL Predict the Pick  2024              2   7.0
# 466  159        Quinn        NFL Predict the Pick  2024              2   8.0
# 467  109          Ari        NFL Predict the Pick  2024              2   9.0
# 468  106         Kyle        NFL Predict the Pick  2024              2  10.0
# 469  123        Nakul        NFL Predict the Pick  2025              3   1.0
# 470  187   Nate Jones        NFL Predict the Pick  2025              3   2.0
# 471  159        Quinn        NFL Predict the Pick  2025              3   3.0
# 472  104       Double        NFL Predict the Pick  2025              3   4.0
# 473  164         Noah        NFL Predict the Pick  2025              3   5.0
# 474  106         Kyle        NFL Predict the Pick  2025              3   6.0
# 475  114         Jack        NFL Predict the Pick  2025              3   7.5
# 476  124        Mitch        NFL Predict the Pick  2025              3   7.5
# 477  163         Josh        NFL Predict the Pick  2025              3   9.0
# 478  109          Ari        NFL Predict the Pick  2025              3  10.0
# 479  102        Devin        NFL Predict the Pick  2025              3  11.0
# 480  105       Graham        NFL Predict the Pick  2025              3  12.0
# 481  113        Davis        NFL Predict the Pick  2025              3  13.0
# 482  109          Ari             Pigskin Pick'Em  2022              1   1.0
# 483  102        Devin             Pigskin Pick'Em  2022              1   2.0
# 484  124        Mitch             Pigskin Pick'Em  2022              1   3.0
# 485  114         Jack             Pigskin Pick'Em  2022              1   4.0
# 486  105       Graham             Pigskin Pick'Em  2022              1   5.0
# 487  104       Double             Pigskin Pick'Em  2022              1   6.0
# 488  102        Devin             Pigskin Pick'Em  2023              2   1.0
# 489  106         Kyle             Pigskin Pick'Em  2023              2   2.0
# 490  159        Quinn             Pigskin Pick'Em  2023              2   3.0
# 491  162         Chad             Pigskin Pick'Em  2023              2   4.0
# 492  104       Double             Pigskin Pick'Em  2023              2   5.0
# 493  109          Ari             Pigskin Pick'Em  2023              2   6.0
# 494  114         Jack             Pigskin Pick'Em  2023              2   7.0
# 495  106         Kyle             Pigskin Pick'Em  2024              3   1.0
# 496  178       Nathan             Pigskin Pick'Em  2024              3   3.0
# 497  102        Devin             Pigskin Pick'Em  2024              3   3.0
# 498  109          Ari             Pigskin Pick'Em  2024              3   3.0
# 499  159        Quinn             Pigskin Pick'Em  2024              3   5.0
# 500  104       Double             Pigskin Pick'Em  2024              3   6.0
# 501  179         Verg             Pigskin Pick'Em  2024              3   7.0
# 502  184       Quiche             Pigskin Pick'Em  2024              3   8.0
# 503  162         Chad             Pigskin Pick'Em  2024              3   9.0
# 504  156       Landon             Pigskin Pick'Em  2024              3  10.0
# 505  105       Graham             Pigskin Pick'Em  2024              3  11.0
# 506  123        Nakul             Pigskin Pick'Em  2024              3  12.0
# 507  114         Jack             Pigskin Pick'Em  2024              3  13.0
# 508  124        Mitch             Pigskin Pick'Em  2024              3  14.0
# 509  113        Davis        Eliminator Challenge  2022              1   2.0
# 510  102        Devin        Eliminator Challenge  2022              1   2.0
# 511  124        Mitch        Eliminator Challenge  2022              1   2.0
# 512  104       Double        Eliminator Challenge  2022              1   6.5
# 513  105       Graham        Eliminator Challenge  2022              1   6.5
# 514  123        Nakul        Eliminator Challenge  2022              1   6.5
# 515  122     Nicholas        Eliminator Challenge  2022              1   6.5
# 516  114         Jack        Eliminator Challenge  2022              1   6.5
# 517  109          Ari        Eliminator Challenge  2022              1   6.5
# 518  105       Graham        Eliminator Challenge  2023              2   1.0
# 519  159        Quinn        Eliminator Challenge  2023              2   2.0
# 520  102        Devin        Eliminator Challenge  2023              2   4.0
# 521  109          Ari        Eliminator Challenge  2023              2   4.0
# 522  106         Kyle        Eliminator Challenge  2023              2   4.0
# 523  114         Jack        Eliminator Challenge  2023              2   6.5
# 524  124        Mitch        Eliminator Challenge  2023              2   6.5
# 525  123        Nakul        Eliminator Challenge  2023              2   8.5
# 526  104       Double        Eliminator Challenge  2023              2   8.5
# 527  105       Graham        Eliminator Challenge  2024              3   2.0
# 528  178       Nathan        Eliminator Challenge  2024              3   2.0
# 529  159        Quinn        Eliminator Challenge  2024              3   2.0
# 530  162         Chad        Eliminator Challenge  2024              3   7.5
# 531  104       Double        Eliminator Challenge  2024              3   7.5
# 532  102        Devin        Eliminator Challenge  2024              3   7.5
# 533  163         Josh        Eliminator Challenge  2024              3   7.5
# 534  114         Jack        Eliminator Challenge  2024              3   7.5
# 535  109          Ari        Eliminator Challenge  2024              3   7.5
# 536  106         Kyle        Eliminator Challenge  2024              3   7.5
# 537  124        Mitch        Eliminator Challenge  2024              3   7.5
# 538  102        Devin          Pigskin Win Totals  2022              1   1.0
# 539  109          Ari          Pigskin Win Totals  2022              1   2.5
# 540  162         Chad          Pigskin Win Totals  2022              1   2.5
# 541  114         Jack          Pigskin Win Totals  2022              1   4.0
# 542  124        Mitch          Pigskin Win Totals  2022              1   5.0
# 543  106         Kyle          Pigskin Win Totals  2024              2   1.0
# 544  104       Double          Pigskin Win Totals  2024              2   2.0
# 545  178       Nathan          Pigskin Win Totals  2024              2   3.0
# 546  124        Mitch          Pigskin Win Totals  2024              2   5.0
# 547  105       Graham          Pigskin Win Totals  2024              2   5.0
# 548  163         Josh          Pigskin Win Totals  2024              2   5.0
# 549  102        Devin          Pigskin Win Totals  2024              2   8.0
# 550  162         Chad          Pigskin Win Totals  2024              2   8.0
# 551  109          Ari          Pigskin Win Totals  2024              2   8.0
# 552  107         Zack                  Bowl Mania  2021              1   1.0
# 553  114         Jack                  Bowl Mania  2021              1   2.0
# 554  121       Falcon                  Bowl Mania  2021              1   3.0
# 555  104       Double                  Bowl Mania  2021              1   4.0
# 556  102        Devin                  Bowl Mania  2021              1   6.0
# 557  105       Graham                  Bowl Mania  2021              1   6.0
# 558  106         Kyle                  Bowl Mania  2021              1   6.0
# 895    Football          0         1          0          0           12.0
# 896    Football          0         1          0          0           12.0
# 897    Football          0         1          0          0           12.0
# 898      Hockey          1         0          0          0            6.0
# 899      Hockey          1         0          0          0            6.0
# 900      Hockey          1         0          0          0            6.0
# 901      Hockey          1         0          0          0            6.0
# 902      Hockey          1         0          0          0            6.0
# 903      Hockey          1         0          0          0            6.0
# 904    Football          0         0          1          0           12.0
# 905    Football          0         0          1          0           12.0
# 906    Football          0         0          1          0           12.0
# 907    Football          0         0          1          0           12.0
# 908    Football          0         0          1          0           12.0
# 909    Football          0         0          1          0           12.0
# 910    Football          0         0          1          0           12.0
# 911    Football          0         0          1          0           12.0
# 912    Football          0         0          1          0           12.0
# 913    Football          0         0          1          0           12.0
# 914    Football          0         0          1          0           11.0
# 915    Football          0         0          1          0           11.0
# 916    Football          0         0          1          0           11.0
# 917    Football          0         0          1          0           11.0
# 918    Football          0         0          1          0           11.0
# 919    Football          0         0          1          0           11.0
# 920    Football          0         0          1          0           11.0
# 921    Football          0         0          1          0           11.0
# 922    Football          0         0          1          0           11.0
# 923    Football          0         0          1          0            8.0
# 924    Football          0         0          1          0            8.0
# 925    Football          0         0          1          0            8.0
# 926    Football          0         0          1          0            8.0
# 927    Football          0         0          1          0            8.0
# 928    Football          0         0          1          0            8.0
# 929    Football          0         0          1          0            8.0
# 930    Football          0         0          1          0            8.0

# %% [markdown]
# ## Compute Adjusted Percentile

# %% [markdown]
# ### In order to account for the difference in competition size, an adjusted percentile needs to be implemented based on the following formula:

# %% [markdown]
# $$
# \text{Adjusted Percentile} = \left( \frac{n - \text{rank}}{n - 1} \right) \cdot \ln(1 + n)
# $$
#
# where:
#
# - $\text{rank}$ is the position of an individual within the league, with 1 being the highest position.
# - $n$ is the total number of participants in the league.

# %%
# Define the function to calculate Adjusted Percentile
def calculate_adjusted_percentile(row):
    n = row['Total Players']
    rank = row['Rank']
    if n > 1:
        adjusted_percentile = ((n - rank) / (n - 1)) * np.log(1 + n)
    else:
        adjusted_percentile = np.log(2)  # When there's only one player, use log(2) as a placeholder
    return adjusted_percentile

# %%
# Define the function to calculate the Perfect Adjusted Percentile
def calculate_perfect_adjusted_percentile(row):
    n = row['Total Players']
    # Ideal scenario: player always ranks 1st
    ideal_rank = 1
    if n > 1:
        perfect_adjusted_percentile = ((n - ideal_rank) / (n - 1)) * np.log(1 + n)
    else:
        perfect_adjusted_percentile = np.log(2)  # When there's only one league, use log(2) as a placeholder
    return perfect_adjusted_percentile

# %%
# Apply the function to compute Adjusted Percentile for each row
data['Adjusted Percentile'] = data.apply(calculate_adjusted_percentile, axis=1)
data['Perfect Adjusted Percentile'] = data.apply(calculate_perfect_adjusted_percentile, axis=1)

data.head()
# Out:
#     ID   Name      League  Year  League Year #  Rank     Sport  Minigame?  \
# 0  112  Grant  FFN Alumni  2021              1   1.0  Football          0
# 1  109    Ari  FFN Alumni  2021              1   2.0  Football          0
# 2  103    Cam  FFN Alumni  2021              1   3.0  Football          0
# 3  106   Kyle  FFN Alumni  2021              1   4.0  Football          0
# 4  127   DMac  FFN Alumni  2021              1   5.0  Football          0
#
#    Dynasty?  Bestball?  Orphaned?  Total Players  Adjusted Percentile  \
# 0         1          0          0           12.0             2.564949
# 1         1          0          0           12.0             2.331772
# 2         1          0          0           12.0             2.098595
# 3         1          0          0           12.0             1.865418
# 4         1          0          0           12.0             1.632241
#
#    Perfect Adjusted Percentile
# 0                     2.564949
# 1                     2.564949
# 2                     2.564949
# 3                     2.564949
# 4                     2.564949

# %% [markdown]
# # Create Summary Statistics for Each Player

# %% [markdown]
# ### For the summary statistics, the data can be filtered to compute the results of various subsets of the overall dataset. The function below is implemented to handle such filtering and documentation is provided below as well

# %%
# Function to filter the DataFrame based on various column criteria
def filter_dataframe(df, ID=None, Name=None, League=None, Year=None, League_Year_Number=None, 
                     Rank=None, Sport=None, Minigame=None, Dynasty=None, Bestball=None, 
                     Orphaned=None, Total_Players=None, Adjusted_Percentile=None):
    filtered_df = df.copy()
    
    if ID is not None:
        filtered_df = filtered_df[filtered_df['ID'] == ID]
    if Name is not None:
        filtered_df = filtered_df[filtered_df['Name'] == Name]
    if League is not None:
        filtered_df = filtered_df[filtered_df['League'] == League]
    if Year is not None:
        filtered_df = filtered_df[filtered_df['Year'] == Year]
    if League_Year_Number is not None:
        filtered_df = filtered_df[filtered_df['League Year #'] == League_Year_Number]
    if Rank is not None:
        filtered_df = filtered_df[filtered_df['Rank'] == Rank]
    if Sport is not None:
        filtered_df = filtered_df[filtered_df['Sport'] == Sport]
    if Minigame is not None:
        filtered_df = filtered_df[filtered_df['Minigame?'] == Minigame]
    if Dynasty is not None:
        filtered_df = filtered_df[filtered_df['Dynasty?'] == Dynasty]
    if Bestball is not None:
        filtered_df = filtered_df[filtered_df['Bestball?'] == Bestball]
    if Orphaned is not None:
        filtered_df = filtered_df[filtered_df['Orphaned?'] == Orphaned]
    if Total_Players is not None:
        filtered_df = filtered_df[filtered_df['Total Players'] == Total_Players]
    if Adjusted_Percentile is not None:
        # Adjusted Percentile might need a range or exact match, here it's considered as exact match for simplicity
        filtered_df = filtered_df[filtered_df['Adjusted Percentile'] == Adjusted_Percentile]
    
    return filtered_df

# %%
"""
Function Usage Example:

The `filter_dataframe` function can be used to filter the data based on various criteria.
Each parameter corresponds to a column in the DataFrame, and you can specify filters for any combination of these columns.
If a parameter is not specified (left as None), no filter is applied for that column.

Parameters:
ID: Filter by the unique ID of the participant (e.g., 112.0)
Name: Filter by the participant's name (e.g., 'Grant')
League: Filter by the league name (e.g., 'FFN Alumni')
Year: Filter by the year of the league (e.g., 2021)
League_Year_Number: Filter by the specific league year number (e.g., 1)
Rank: Filter by the rank within the league (e.g., 1.0 for first place)
Sport: Filter by the sport type (e.g., 'Football')
Minigame: Filter by whether it is a minigame (1 for yes, 0 for no)
Dynasty: Filter by whether it is a dynasty league (1 for yes, 0 for no)
Bestball: Filter by whether it is a bestball league (1 for yes, 0 for no)
Orphaned: Filter by whether the team was orphaned (1 for yes, 0 for no)
Total_Players: Filter by the total number of players in the league (e.g., 12)
Adjusted_Percentile: Filter by the adjusted percentile score (e.g., 2.564949)
""";
# Example:
# To filter the data for leagues from the year 2021 that are in the sport of Football, use the following:
# filtered_data = filter_dataframe(data, Year=2021, Sport='Football')
# filtered_data.head()

# %%
filtered_data = filter_dataframe(data,Orphaned=0)
filtered_data.reset_index(drop=True, inplace=True)
filtered_data.head()
# Out:
#     ID   Name      League  Year  League Year #  Rank     Sport  Minigame?  \
# 0  112  Grant  FFN Alumni  2021              1   1.0  Football          0
# 1  109    Ari  FFN Alumni  2021              1   2.0  Football          0
# 2  103    Cam  FFN Alumni  2021              1   3.0  Football          0
# 3  106   Kyle  FFN Alumni  2021              1   4.0  Football          0
# 4  127   DMac  FFN Alumni  2021              1   5.0  Football          0
#
#    Dynasty?  Bestball?  Orphaned?  Total Players  Adjusted Percentile  \
# 0         1          0          0           12.0             2.564949
# 1         1          0          0           12.0             2.331772
# 2         1          0          0           12.0             2.098595
# 3         1          0          0           12.0             1.865418
# 4         1          0          0           12.0             1.632241
#
#    Perfect Adjusted Percentile
# 0                     2.564949
# 1                     2.564949
# 2                     2.564949
# 3                     2.564949
# 4                     2.564949

# %% [markdown]
# ### League Performance Index (LPI) quantifies a player's bayesian average adjusted percentile finish. Each player's adjusted percentile finish across all of their league ranking results is computed to account for the variation in the total number of players in a given league. Based on a player's total adjusted percentile finish, the bayesian average is then calculated to account for the variation in the total number of leagues a given player has participated in.

# %% [markdown]
# #### Function to generate summary statistics for each player

# %%
def summarize_player_statistics(df):
    # Aggregate basic statistics
    player_summary = df.groupby(['ID', 'Name']).agg(
        Average_Rank=('Rank', 'mean'),
        Total_Adjusted_Percentile=('Adjusted Percentile', 'sum'),
        Average_Adjusted_Percentile=('Adjusted Percentile', 'mean'),
        Total_Perfect_Adjusted_Percentile=('Perfect Adjusted Percentile', 'sum'),
        Average_Perfect_Adjusted_Percentile=('Perfect Adjusted Percentile', 'mean')
    ).reset_index()
    
    # Ratio of player's average to perfect adjusted percentile
    player_summary['Adjusted_Percentile_Ratio'] = player_summary['Average_Adjusted_Percentile'] / player_summary['Average_Perfect_Adjusted_Percentile']
    
    # Correcting Total Leagues to simply count the number of times an ID/Name combination appears in the DataFrame
    player_summary['Total_Leagues'] = df.groupby(['ID', 'Name']).size().reset_index(name='Total_Leagues')['Total_Leagues']
    
    # Calculate C as the average of the Total_Leagues column
    C = player_summary['Total_Leagues'].mean()

    # Calculate the overall mean score (M) across all players
    M = player_summary['Average_Adjusted_Percentile'].mean()
    
    # Calculate Bayesian average for each player
    player_summary['LPI'] = (C * M + player_summary['Total_Leagues'] * player_summary['Average_Adjusted_Percentile']) / (C + player_summary['Total_Leagues'])
    
    # Create a pivot table to count participation in each league
    league_participation = df.pivot_table(index=['ID', 'Name'], columns='League', aggfunc='size', fill_value=0)
    
    # Combine the aggregated stats and league participation into one DataFrame
    player_summary_final = pd.merge(player_summary, league_participation.reset_index(), on=['ID', 'Name'], how='left')
    
    # Adjusting the order of the columns to move Total_Leagues right after the Name column
    cols = ['ID', 'Name', 'Total_Leagues', 'Average_Rank', 'Total_Adjusted_Percentile', 'Average_Adjusted_Percentile', 'Total_Perfect_Adjusted_Percentile','Average_Perfect_Adjusted_Percentile',
            'Adjusted_Percentile_Ratio', 'LPI'] + [col for col in league_participation.columns if col not in ['ID', 'Name']]
    player_summary_final_adjusted = player_summary_final[cols]
    
    # Sort by Adjusted_Percentile_Ratio from largest to smallest
    player_summary_final_sorted = player_summary_final_adjusted.sort_values(by='LPI', ascending=False)

    return player_summary_final_sorted

# Example usage:
# player_summary_final_adjusted = summarize_player_statistics(data)
# player_summary_final_adjusted.head()

# %%
summary_stats_df = summarize_player_statistics(filtered_data)
summary_stats_df.head()
# Out:
#      ID    Name  Total_Leagues  Average_Rank  Total_Adjusted_Percentile  \
# 2   102   Devin             89      3.915730                 146.704280
# 41  162    Chad             44      4.340909                  70.707179
# 9   112   Grant             11      4.454545                  19.325977
# 61  184  Quiche              3      3.333333                   6.884659
# 55  178  Nathan              9      6.722222                  13.883201
#
#     Average_Adjusted_Percentile  Total_Perfect_Adjusted_Percentile  \
# 2                      1.648363                         212.733692
# 41                     1.606981                         108.127111
# 9                      1.756907                          28.493439
# 61                     2.294886                           8.342840
# 55                     1.542578                          23.696227
#
#     Average_Perfect_Adjusted_Percentile  Adjusted_Percentile_Ratio       LPI  \
# 2                              2.390266                   0.689615  1.584792
# 41                             2.457434                   0.653926  1.503459
# 9                              2.590313                   0.678261  1.431507
# 61                             2.780947                   0.825218  1.371765
# 55                             2.632914                   0.585882  1.317150
#
#     ...  NFL Predict the Pick  NHL Bracket Challenge  NHL Predict The Pick  \
# 2   ...                     3                      2                     2
# 41  ...                     1                      0                     0
# 9   ...                     0                      0                     0
# 61  ...                     0                      0                     0
# 55  ...                     0                      0                     0
#
#     P4 CFF Bestball  Pigskin Pick'Em  Pigskin Win Totals  Puck Redraft  \
# 2                 1                3                   2             3
# 41                1                2                   2             1
# 9                 0                0                   0             0
# 61                0                1                   0             0
# 55                0                1                   1             0
#
#     Sex Havers  Stanley Cup Fantasy  dyNASTY
# 2            3                    4        2
# 41           0                    2        0
# 9            0                    0        0
# 61           0                    0        0
# 55           0                    0        0
#
# [5 rows x 47 columns]

# %% [markdown]
# ### League Performance Index Plus (LPI+) takes a player's League Performance Index (LPI) and normalizes the number across the entire FFN universe. It then adjusts so a score of 100 is league average, and 150 is 50 percent better than the league average.

# %%
# Compute the average of the LPI column
overall_mean_bayesian_average = summary_stats_df['LPI'].mean()

# Calculate the scale factor to adjust the Bayesian average to a scale where the average is 100
scale_factor = 100 / overall_mean_bayesian_average

# Apply the scale factor to each player's Bayesian average to adjust it to the new scale
summary_stats_df['LPI+'] = (summary_stats_df['LPI'] * scale_factor).round(2)

# Display the DataFrame to verify the new scaled scores
summary_stats_df[['ID', 'Name', 'Total_Leagues', 'Average_Rank', 'Total_Adjusted_Percentile', 'Average_Adjusted_Percentile', 'Total_Perfect_Adjusted_Percentile','Average_Perfect_Adjusted_Percentile',
            'Adjusted_Percentile_Ratio', 'LPI', 'LPI+']].head()
# Out:
#      ID    Name  Total_Leagues  Average_Rank  Total_Adjusted_Percentile  \
# 2   102   Devin             89      3.915730                 146.704280
# 41  162    Chad             44      4.340909                  70.707179
# 9   112   Grant             11      4.454545                  19.325977
# 61  184  Quiche              3      3.333333                   6.884659
# 55  178  Nathan              9      6.722222                  13.883201
#
#     Average_Adjusted_Percentile  Total_Perfect_Adjusted_Percentile  \
# 2                      1.648363                         212.733692
# 41                     1.606981                         108.127111
# 9                      1.756907                          28.493439
# 61                     2.294886                           8.342840
# 55                     1.542578                          23.696227
#
#     Average_Perfect_Adjusted_Percentile  Adjusted_Percentile_Ratio       LPI  \
# 2                              2.390266                   0.689615  1.584792
# 41                             2.457434                   0.653926  1.503459
# 9                              2.590313                   0.678261  1.431507
# 61                             2.780947                   0.825218  1.371765
# 55                             2.632914                   0.585882  1.317150
#
#       LPI+
# 2   134.53
# 41  127.62
# 9   121.52
# 61  116.44
# 55  111.81

# %% [markdown]
# ## Plot of League Performance Index Plus (LPI+)

# %%
# Reverse the order of the DataFrame
summary_stats_df_sorted_reverse = summary_stats_df[::-1]

# Calculate deviations from 100 (both above and below)
deviation_above = summary_stats_df_sorted_reverse['LPI+'].max() - 100
deviation_below = 100 - summary_stats_df_sorted_reverse['LPI+'].min()

# Find the maximum deviation to ensure symmetry around 100
max_deviation = max(deviation_above, deviation_below)

# Set x-axis limits to center 100 in the plot
x_min = 100 - max_deviation - 5  # Adding a small buffer
x_max = 100 + max_deviation + 5  # Adding a small buffer

plt.figure(figsize=(8.75,9.5), dpi=250)
plt.barh(summary_stats_df_sorted_reverse['Name'], summary_stats_df_sorted_reverse['LPI+'], color='skyblue')
plt.axvline(100, color='red', linestyle='--', label='Average=100')

plt.xlim([x_min, x_max])

plt.xlabel('League Performance Index Plus')
plt.ylabel('Player')
plt.title('FFN Universe League Performance Index Plus (LPI+)')
plt.legend(loc='upper left')

# Adding data labels
for index, value in enumerate(summary_stats_df_sorted_reverse['LPI+']):
    plt.text(value, index, f"{value:.2f}", va='center')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Code to develop table for paper

# %%
pd.set_option('display.max_rows', None)  # This
summary_stats_df_rounded = summary_stats_df.round(2)
summary_stats_df_reset = summary_stats_df_rounded.reset_index(drop=True)
summary_stats_df_reset.index = summary_stats_df_reset.index + 1
summary_stats_df_reset[['Name', 'Total_Leagues', 'Average_Rank', 'Average_Adjusted_Percentile', 'LPI', 'LPI+']]
# Out:
#            Name  Total_Leagues  Average_Rank  Average_Adjusted_Percentile  \
# 1         Devin             89          3.92                         1.65
# 2          Chad             44          4.34                         1.61
# 3         Grant             11          4.45                         1.76
# 4        Quiche              3          3.33                         2.29
# 5        Nathan              9          6.72                         1.54
# 6       Fantasy              4          6.00                         1.81
# 7          John              6          6.00                         1.63
# 8        Graham             72          5.06                         1.33
# 9       Broseph              2          2.50                         2.22
# 10        Jorge              4          5.75                         1.74
# 11       Double             63          5.64                         1.31
# 12        Aaron              3          4.33                         1.79
# 13        Jonah              1          1.00                         2.56
# 14        Quinn             30          5.55                         1.30
# 15       Deaven              2          4.00                         1.87
# 16         Soup             14          5.89                         1.30
# 17            J             10          5.20                         1.31
# 18        Dante              2          5.00                         1.63
# 19       Austin              2          6.75                         1.62
# 20        Kevin              3          5.67                         1.48
# 21         DMac              4          6.00                         1.40
# 22         Kyle             55          5.88                         1.23
# 23        Nakul             32          6.16                         1.24
# 24       Falcon              6          4.33                         1.32
# 25       Josh S              2          5.50                         1.52
# 26          Ari             41          6.02                         1.22
# 27       Landon             24          6.38                         1.20
# 28        Fawaz              1          6.00                         1.40
# 29      Matthew              2          6.50                         1.28
# 30      Anthony              2          6.50                         1.28
# 31       George              3          6.67                         1.24
# 32    1st Quinn              1          5.00                         1.33
# 33       Kelsey              3          4.00                         1.18
# 34         Eric              1          7.00                         1.17
# 35      Brandon              2          7.00                         1.17
# 36         Josh             38          6.33                         1.17
# 37         Neil              3          7.33                         1.09
# 38       Alyvia              3          8.67                         1.08
# 39         Trey             17          5.94                         1.14
# 40          Cam             12          6.71                         1.11
# 41       Andrew              2          8.00                         0.93
# 42       Daniel              7          5.50                         1.06
# 43     Landon K              1          6.00                         0.63
# 44         Zack              6          7.33                         1.04
# 45      Tristan             11          6.36                         1.08
# 46         Nate              2          8.50                         0.82
# 47       Thomas              2          8.50                         0.82
# 48  Ben Shelton              2          5.50                         0.78
# 49   Nate Jones              3          8.00                         0.89
# 50         Cory              1          7.00                         0.31
# 51         Dave              2          9.00                         0.70
# 52       Steven             10          8.60                         1.02
# 53         Noah             43          6.64                         1.08
# 54         Nick              3          8.67                         0.78
# 55         Ryan              1         10.00                         0.00
# 56  Justin Hill              1          8.00                         0.00
# 57      Jackson              3          9.00                         0.70
# 58        Craig              2         12.25                         0.47
# 59     Nicholas              6          6.75                         0.87
# 60        Davis             17          6.82                         0.99
# 61   Other Jack              3          9.67                         0.54
# 62      Charles              9          6.78                         0.85
# 63         Jude              4          9.50                         0.58
# 64        Mitch             59          6.65                         0.98
# 65         Jack             72          6.55                         0.98
# 66         Joel              9          9.72                         0.75
# 67         Verg              7         11.93                         0.63
# 68          Ben              8          8.50                         0.59
#
#      LPI    LPI+
# 1   1.58  134.53
# 2   1.50  127.62
# 3   1.43  121.52
# 4   1.37  116.44
# 5   1.32  111.81
# 6   1.31  111.45
# 7   1.31  111.17
# 8   1.30  110.63
# 9   1.30  110.54
# 10  1.30  110.16
# 11  1.29  109.20
# 12  1.28  108.64
# 13  1.26  107.25
# 14  1.26  107.03
# 15  1.26  106.72
# 16  1.24  104.91
# 17  1.23  104.36
# 18  1.23  104.18
# 19  1.23  104.08
# 20  1.22  103.86
# 21  1.22  103.58
# 22  1.22  103.32
# 23  1.22  103.20
# 24  1.21  103.03
# 25  1.21  102.90
# 26  1.21  102.70
# 27  1.19  100.88
# 28  1.18  100.46
# 29  1.18  100.36
# 30  1.18  100.36
# 31  1.18  100.28
# 32  1.18  100.07
# 33  1.17   99.35
# 34  1.17   99.10
# 35  1.17   99.09
# 36  1.17   98.95
# 37  1.15   97.89
# 38  1.15   97.71
# 39  1.15   97.63
# 40  1.14   96.85
48	Cory	1	7.00	0.31	1.08	91.54
49	Nakul	13	6.77	1.02	1.08	91.21
50	Nick	2	9.50	0.58	1.06	89.67
51	Verg	2	13.50	0.57	1.06	89.53
52	Nate	1	12.00	0.00	1.05	88.74
53	Ryan	1	10.00	0.00	1.05	88.74
54	Nicholas	6	6.75	0.87	1.05	88.58
55	Jack	43	6.07	1.02	1.05	88.21
56	Mitch	27	6.30	0.95	1.01	84.97
57	Joel	6	10.08	0.77	1.01	84.95
58	Steven	3	12.33	0.52	1.00	84.68
59	Noah	20	7.05	0.92	1.00	84.10
60	Jude	3	10.00	0.47	0.99	83.56
61	Ben	7	8.14	0.64	0.93	78.83
"""

# Improved regex to handle names with spaces and more than one word
latex_rows = []

# Split the string into lines
data_lines = data_str.strip().split('\n')

# Process each line with regex
for line in data_lines:
    # Match the line format with regex
    match = re.match(r'(\d+)\s+([\w\s]+)\s+(\d+)\s+([\d.]+)\s+([\d.]+)\s+([\d.]+)\s+([\d.]+)', line)
    if match:
        # Format the matched groups into LaTeX table row format
        latex_row = ' & '.join(match.groups()) + r' \\'
        latex_rows.append(latex_row)

# Join all rows into a single string with line breaks
latex_table_content = '\n'.join(latex_rows)

# Print the result or write it to a file
print(latex_table_content)
# Out:
# 1 & Devin & 51 & 3.96 & 1.63 & 1.56 & 131.96 \\
# 2 & Chad & 23 & 3.67 & 1.69 & 1.55 & 131.00 \\
# 3 & Grant & 9 & 4.22 & 1.81 & 1.50 & 126.84 \\
# 4 & Landon & 11 & 5.18 & 1.55 & 1.38 & 116.88 \\
# 5 & John & 4 & 6.00 & 1.75 & 1.36 & 114.70 \\
# 6 & Jorge & 1 & 4.00 & 2.63 & 1.33 & 112.18 \\
# 7 & Kevin & 2 & 4.00 & 1.87 & 1.31 & 110.36 \\
# 8 & George & 2 & 4.00 & 1.87 & 1.31 & 110.36 \\
# 9 & Aaron & 2 & 4.00 & 1.87 & 1.31 & 110.36 \\
# 10 & Graham & 42 & 4.96 & 1.33 & 1.30 & 109.96 \\
# 11 & Trey & 10 & 5.10 & 1.41 & 1.30 & 109.75 \\
# 12 & Broseph & 1 & 2.00 & 2.33 & 1.30 & 109.55 \\
# 13 & Fantasy & 3 & 7.33 & 1.63 & 1.29 & 109.28 \\
# 14 & J & 7 & 4.86 & 1.43 & 1.29 & 109.01 \\
# 15 & Dante & 2 & 5.00 & 1.63 & 1.26 & 106.60 \\
# 16 & Quinn & 12 & 4.92 & 1.32 & 1.26 & 106.26 \\
# 17 & Deaven & 1 & 4.00 & 1.87 & 1.25 & 105.39 \\
# 18 & Falcon & 6 & 4.33 & 1.32 & 1.23 & 104.21 \\
# 19 & Double & 37 & 5.70 & 1.23 & 1.22 & 103.27 \\
# 20 & Nathan & 3 & 8.67 & 1.32 & 1.21 & 102.34 \\
# 21 & Josh S & 1 & 5.50 & 1.52 & 1.21 & 102.27 \\
# 22 & Ari & 27 & 5.74 & 1.21 & 1.20 & 101.36 \\
# 23 & Cam & 9 & 6.06 & 1.22 & 1.20 & 101.24 \\
# 24 & Fawaz & 1 & 6.00 & 1.40 & 1.20 & 101.23 \\
# 25 & Dave & 1 & 6.00 & 1.40 & 1.20 & 101.23 \\
# 26 & Anthony & 2 & 6.50 & 1.28 & 1.20 & 100.95 \\
# 27 & Matthew & 2 & 6.50 & 1.28 & 1.20 & 100.95 \\
# 28 & 1st Quinn & 1 & 5.00 & 1.33 & 1.19 & 100.63 \\
# 29 & Kelsey & 1 & 4.00 & 1.26 & 1.18 & 99.94 \\
# 30 & Davis & 13 & 5.77 & 1.19 & 1.18 & 99.91 \\
# 31 & Tristan & 6 & 6.17 & 1.18 & 1.18 & 99.25 \\
# 32 & Brandon & 2 & 7.00 & 1.17 & 1.17 & 99.07 \\
# 33 & Zack & 5 & 6.80 & 1.16 & 1.17 & 98.74 \\
# 34 & Kyle & 34 & 5.91 & 1.17 & 1.17 & 98.60 \\
# 35 & Daniel & 2 & 5.50 & 1.05 & 1.15 & 97.22 \\
# 36 & Neil & 2 & 7.50 & 1.05 & 1.15 & 97.19 \\
# 37 & Ben Shelton & 1 & 5.00 & 0.94 & 1.15 & 97.14 \\
# 38 & Josh & 17 & 6.47 & 1.13 & 1.15 & 96.86 \\
# 39 & Soup & 8 & 6.62 & 1.09 & 1.13 & 95.59 \\
# 40 & DMac & 3 & 7.67 & 1.01 & 1.13 & 95.58 \\
# 41 & Andrew & 2 & 8.00 & 0.93 & 1.13 & 95.31 \\
# 42 & Alyvia & 1 & 9.00 & 0.70 & 1.13 & 94.98 \\
# 43 & Charles & 4 & 5.75 & 1.00 & 1.12 & 94.45 \\
# 44 & Landon K & 1 & 6.00 & 0.63 & 1.12 & 94.34 \\
# 45 & Thomas & 2 & 8.50 & 0.82 & 1.11 & 93.43 \\
# 46 & Jackson & 2 & 8.50 & 0.82 & 1.11 & 93.43 \\
# 47 & Other Jack & 2 & 9.00 & 0.70 & 1.08 & 91.55 \\
# 48 & Cory & 1 & 7.00 & 0.31 & 1.08 & 91.54 \\
# 49 & Nakul & 13 & 6.77 & 1.02 & 1.08 & 91.21 \\
# 50 & Nick & 2 & 9.50 & 0.58 & 1.06 & 89.67 \\
# 51 & Verg & 2 & 13.50 & 0.57 & 1.06 & 89.53 \\
# 52 & Nate & 1 & 12.00 & 0.00 & 1.05 & 88.74 \\
# 53 & Ryan & 1 & 10.00 & 0.00 & 1.05 & 88.74 \\
# 54 & Nicholas & 6 & 6.75 & 0.87 & 1.05 & 88.58 \\
# 55 & Jack & 43 & 6.07 & 1.02 & 1.05 & 88.21 \\
# 56 & Mitch & 27 & 6.30 & 0.95 & 1.01 & 84.97 \\
# 57 & Joel & 6 & 10.08 & 0.77 & 1.01 & 84.95 \\
# 58 & Steven & 3 & 12.33 & 0.52 & 1.00 & 84.68 \\
# 59 & Noah & 20 & 7.05 & 0.92 & 1.00 & 84.10 \\
# 60 & Jude & 3 & 10.00 & 0.47 & 0.99 & 83.56 \\
# 61 & Ben & 7 & 8.14 & 0.64 & 0.93 & 78.83 \\

# %%
#5/2/2025
data_str = """
64	Jack	65	6.78	0.94	0.97	83.08
65	Verg	7	11.93	0.63	0.97	82.95
66	Ben	8	8.50	0.59	0.94	80.13
"""

# Improved regex to handle names with spaces and more than one word
latex_rows = []

# Split the string into lines
data_lines = data_str.strip().split('\n')

# Process each line with regex
for line in data_lines:
    # Match the line format with regex
    match = re.match(r'(\d+)\s+([\w\s]+)\s+(\d+)\s+([\d.]+)\s+([\d.]+)\s+([\d.]+)\s+([\d.]+)', line)
    if match:
        # Format the matched groups into LaTeX table row format
        latex_row = ' & '.join(match.groups()) + r' \\'
        latex_rows.append(latex_row)

# Join all rows into a single string with line breaks
latex_table_content = '\n'.join(latex_rows)

# Print the result or write it to a file
print(latex_table_content)
# Out:
# 1 & Devin & 81 & 3.99 & 1.65 & 1.58 & 135.03 \\
# 2 & Chad & 42 & 4.19 & 1.65 & 1.53 & 131.06 \\
# 3 & Grant & 10 & 4.50 & 1.75 & 1.41 & 120.60 \\
# 4 & Quiche & 3 & 3.33 & 2.29 & 1.37 & 116.90 \\
# 5 & Quinn & 27 & 5.26 & 1.42 & 1.33 & 113.98 \\
# 6 & Graham & 65 & 5.01 & 1.37 & 1.33 & 113.97 \\
# 7 & Nathan & 9 & 6.72 & 1.54 & 1.31 & 112.16 \\
# 8 & Fantasy & 4 & 6.00 & 1.81 & 1.31 & 111.69 \\
# 9 & John & 6 & 6.00 & 1.63 & 1.31 & 111.45 \\
# 10 & Broseph & 2 & 2.50 & 2.22 & 1.30 & 110.68 \\
# 11 & Double & 59 & 5.69 & 1.31 & 1.28 & 109.29 \\
# 12 & J & 9 & 4.44 & 1.46 & 1.28 & 109.24 \\
# 13 & Aaron & 3 & 4.33 & 1.79 & 1.27 & 108.73 \\
# 14 & Deaven & 2 & 4.00 & 1.87 & 1.25 & 106.67 \\
# 15 & Jorge & 3 & 7.33 & 1.52 & 1.22 & 104.41 \\
# 16 & Dante & 2 & 5.00 & 1.63 & 1.22 & 104.00 \\
# 17 & Austin & 2 & 6.75 & 1.62 & 1.22 & 103.90 \\
# 18 & Kevin & 3 & 5.67 & 1.48 & 1.21 & 103.72 \\
# 19 & DMac & 4 & 6.00 & 1.40 & 1.21 & 103.48 \\
# 20 & Kyle & 52 & 5.97 & 1.22 & 1.21 & 103.32 \\
# 21 & Falcon & 6 & 4.33 & 1.32 & 1.21 & 102.97 \\
# 22 & Josh S & 2 & 5.50 & 1.52 & 1.20 & 102.67 \\
# 23 & Soup & 12 & 6.29 & 1.25 & 1.20 & 102.40 \\
# 24 & Ari & 40 & 6.12 & 1.20 & 1.19 & 101.27 \\
# 25 & Nakul & 29 & 6.45 & 1.20 & 1.19 & 101.25 \\
# 26 & Landon & 22 & 6.45 & 1.20 & 1.18 & 101.03 \\
# 27 & Josh & 35 & 6.36 & 1.18 & 1.17 & 100.29 \\
# 28 & Daniel & 6 & 5.33 & 1.21 & 1.17 & 100.13 \\
# 29 & Fawaz & 1 & 6.00 & 1.40 & 1.17 & 100.03 \\
# 30 & Anthony & 2 & 6.50 & 1.28 & 1.17 & 99.99 \\
# 31 & Matthew & 2 & 6.50 & 1.28 & 1.17 & 99.99 \\
# 32 & George & 3 & 6.67 & 1.24 & 1.17 & 99.97 \\
# 33 & Tristan & 10 & 6.00 & 1.19 & 1.17 & 99.71 \\
# 34 & Kelsey & 2 & 4.00 & 1.26 & 1.17 & 99.69 \\
# 35 & 1st Quinn & 1 & 5.00 & 1.33 & 1.17 & 99.61 \\
# 36 & Trey & 16 & 5.81 & 1.17 & 1.16 & 99.48 \\
# 37 & Cam & 11 & 6.41 & 1.17 & 1.16 & 99.14 \\
# 38 & Brandon & 2 & 7.00 & 1.17 & 1.16 & 98.66 \\
# 39 & Neil & 3 & 7.33 & 1.09 & 1.14 & 97.46 \\
# 40 & Alyvia & 3 & 8.67 & 1.08 & 1.14 & 97.28 \\
# 41 & Andrew & 2 & 8.00 & 0.93 & 1.12 & 95.99 \\
# 42 & Steven & 9 & 8.67 & 1.08 & 1.12 & 95.77 \\
# 43 & Zack & 6 & 7.33 & 1.04 & 1.12 & 95.56 \\
# 44 & Landon K & 1 & 6.00 & 0.63 & 1.12 & 95.29 \\
# 45 & Thomas & 2 & 8.50 & 0.82 & 1.11 & 94.65 \\
# 46 & Nate & 2 & 8.50 & 0.82 & 1.11 & 94.65 \\
# 47 & Ben Shelton & 2 & 5.50 & 0.78 & 1.10 & 94.29 \\
# 48 & Nate Jones & 3 & 8.00 & 0.89 & 1.10 & 94.26 \\
# 49 & Cory & 1 & 7.00 & 0.31 & 1.09 & 93.36 \\
# 50 & Dave & 2 & 9.00 & 0.70 & 1.09 & 93.32 \\
# 51 & Davis & 16 & 6.56 & 1.04 & 1.09 & 93.06 \\
# 52 & Nick & 3 & 8.67 & 0.78 & 1.08 & 92.46 \\
# 53 & Noah & 39 & 6.81 & 1.06 & 1.08 & 92.31 \\
# 54 & Ryan & 1 & 10.00 & 0.00 & 1.07 & 91.44 \\
# 55 & Justin Hill & 1 & 8.00 & 0.00 & 1.07 & 91.44 \\
# 56 & Jackson & 3 & 9.00 & 0.70 & 1.07 & 91.21 \\
# 57 & Nicholas & 6 & 6.75 & 0.87 & 1.06 & 90.87 \\
# 58 & Craig & 2 & 12.25 & 0.47 & 1.06 & 90.70 \\
# 59 & Charles & 8 & 6.50 & 0.87 & 1.04 & 89.23 \\
# 60 & Other Jack & 3 & 9.67 & 0.54 & 1.04 & 88.70 \\
# 61 & Jude & 4 & 9.50 & 0.58 & 1.02 & 86.99 \\
# 62 & Mitch & 52 & 6.86 & 0.97 & 1.00 & 85.66 \\
# 63 & Joel & 8 & 9.81 & 0.75 & 1.00 & 85.36 \\
# 64 & Jack & 65 & 6.78 & 0.94 & 0.97 & 83.08 \\
# 65 & Verg & 7 & 11.93 & 0.63 & 0.97 & 82.95 \\
# 66 & Ben & 8 & 8.50 & 0.59 & 0.94 & 80.13 \\

# %% [markdown]
# ## Track Performance Over Time

# %%
# May 2025 data
may_2025_data = {
    "Name": [
        "Devin", "Chad", "Grant", "Quiche", "Quinn", "Graham", "Nathan", "Fantasy", "John", "Broseph", "Double",
        "J", "Aaron", "Deaven", "Jorge", "Dante", "Austin", "Kevin", "DMac", "Kyle", "Falcon", "Josh S", "Soup",
        "Ari", "Nakul", "Landon", "Josh", "Daniel", "Fawaz", "Anthony", "Matthew", "George", "Tristan", "Kelsey",
        "1st Quinn", "Trey", "Cam", "Brandon", "Neil", "Alyvia", "Andrew", "Steven", "Zack", "Landon K", "Thomas",
        "Nate", "Ben Shelton", "Nate Jones", "Cory", "Dave", "Davis", "Nick", "Noah", "Ryan", "Justin Hill",
        "Jackson", "Nicholas", "Craig", "Charles", "Other Jack", "Jude", "Mitch", "Joel", "Jack", "Verg", "Ben"
    ],
    "Rank_2025": list(range(1, 67))
}

# May 2024 data
may_2024_data = {
    "Name": [
        "Devin", "Chad", "Grant", "Landon", "John", "Jorge", "Kevin", "George", "Aaron", "Graham", "Trey", "Broseph",
        "Fantasy", "J", "Dante", "Quinn", "Deaven", "Falcon", "Double", "Nathan", "Josh S", "Ari", "Cam", "Fawaz",
        "Dave", "Anthony", "Matthew", "1st Quinn", "Kelsey", "Davis", "Tristan", "Brandon", "Zack", "Kyle", "Daniel",
        "Neil", "Ben Shelton", "Josh", "Soup", "DMac", "Andrew", "Alyvia", "Charles", "Landon K", "Thomas", "Jackson",
        "Other Jack", "Cory", "Nakul", "Nick", "Verg", "Nate", "Ryan", "Nicholas", "Jack", "Mitch", "Joel", "Steven",
        "Noah", "Jude", "Ben"
    ],
    "Rank_2024": list(range(1, 62))
}

# Create DataFrames
df_2025 = pd.DataFrame(may_2025_data)
df_2024 = pd.DataFrame(may_2024_data)

# Merge and calculate rank change
merged_df = pd.merge(df_2025, df_2024, on="Name", how="left")
merged_df["Rank_Change"] = merged_df["Rank_2024"] - merged_df["Rank_2025"]

# Drop missing and convert to int
cleaned_df = merged_df.dropna(subset=["Rank_Change"])
cleaned_df = cleaned_df.astype({"Rank_2025": int, "Rank_2024": int, "Rank_Change": int})

# Sort by Rank_Change descending, break ties with Rank_2025 ascending
sorted_df = cleaned_df.sort_values(by=["Rank_Change", "Rank_2025"], ascending=[False, True]).reset_index(drop=True)

# Print result
sorted_df
# Out:
#            Name  Rank_2025  Rank_2024  Rank_Change
# 0         Nakul         25         49           24
# 1          DMac         19         40           21
# 2          Soup         23         39           16
# 3        Steven         42         58           16
# 4          Kyle         20         34           14
# 5        Nathan          7         20           13
# 6         Quinn          5         16           11
# 7          Josh         27         38           11
# 8        Double         11         19            8
# 9        Daniel         28         35            7
# 10         Nate         46         52            6
# 11         Noah         53         59            6
# 12      Fantasy          8         13            5
# 13       Graham          6         10            4
# 14       Deaven         14         17            3
# 15      Broseph         10         12            2
# 16            J         12         14            2
# 17       Alyvia         40         42            2
# 18        Devin          1          1            0
# 19         Chad          2          2            0
# 20        Grant          3          3            0
# 21       Andrew         41         41            0
# 22     Landon K         44         44            0
# 23       Thomas         45         45            0
# 24        Dante         16         15           -1
# 25       Josh S         22         21           -1
# 26         Cory         49         48           -1
# 27         Ryan         54         53           -1
# 28         Jude         61         60           -1
# 29          Ari         24         22           -2
# 30      Tristan         33         31           -2
# 31         Nick         52         50           -2
# 32       Falcon         21         18           -3
# 33         Neil         39         36           -3
# 34     Nicholas         57         54           -3
# 35         John          9          5           -4
# 36        Aaron         13          9           -4
# 37      Anthony         30         26           -4
# 38      Matthew         31         27           -4
# 39        Fawaz         29         24           -5
# 40       Kelsey         34         29           -5
# 41          Ben         66         61           -5
# 42      Brandon         38         32           -6
# 43        Mitch         62         56           -6
# 44         Joel         63         57           -6
# 45    1st Quinn         35         28           -7
# 46        Jorge         15          6           -9
# 47         Jack         64         55           -9
# 48         Zack         43         33          -10
# 49  Ben Shelton         47         37          -10
# 50      Jackson         56         46          -10
# 51        Kevin         18          7          -11
# 52   Other Jack         60         47          -13
# 53          Cam         37         23          -14
# 54         Verg         65         51          -14
# 55      Charles         59         43          -16
# 56        Davis         51         30          -21
# 57       Landon         26          4          -22
# 58       George         32          8          -24
# 59         Trey         36         11          -25
# 60         Dave         50         25          -25

# %%
# Prepare for plot
sorted_df_plot = sorted_df[::-1].copy()
sorted_df_plot["Label"] = sorted_df_plot.apply(lambda row: f"{row['Name']} (#{row['Rank_2025']})", axis=1)

# Determine x-axis limits for symmetry
deviation_above = sorted_df_plot["Rank_Change"].max()
deviation_below = sorted_df_plot["Rank_Change"].min()
max_deviation = max(abs(deviation_above), abs(deviation_below))
x_min = -max_deviation - 1
x_max = max_deviation + 1

# Plotting
plt.figure(figsize=(10, 10), dpi=250)
plt.barh(sorted_df_plot["Label"], sorted_df_plot["Rank_Change"], color="skyblue")
plt.axvline(0, color="red", linestyle="--", label="No Change (0)")

plt.xlim([x_min, x_max])
plt.xlabel("Rank Change from 2024 to 2025")
plt.ylabel("Player (#2025 Rank)")
plt.title("FFN Universe Rank Change (2025 vs 2024)")
plt.legend(loc="upper left")

# Add change values at bar ends
for index, value in enumerate(sorted_df_plot["Rank_Change"]):
    plt.text(value, index, f"{value:+}", va="center")

plt.grid(axis="y", linestyle="--", alpha=0.6) 
plt.tight_layout()
plt.show()

# %%
# # Initialize a dictionary to store the R^2 values
# r2_values = {}

# # Specify the desired columns for the R^2 analysis
# desired_columns = ['Average_Ranking+', 'Adjusted_Percentile_Ratio', 'Average_Adjusted_Percentile', 'Average_Rank', 'Total_Adjusted_Percentile', 'Total_Leagues']

# # Loop through each of the desired columns and perform linear regression against 'Bayesian_Average'
# for column in desired_columns:
#     # Ensure the column is not 'Bayesian_Average' itself
#     if column != 'Average_Ranking':
#         # Reshape data for sklearn (needs 2D arrays for features)
#         X = summary_stats_df[[column]].values.reshape(-1, 1)
#         y = summary_stats_df['Average_Ranking'].values

#         # Initialize and fit the model
#         model = LinearRegression()
#         model.fit(X, y)

#         # Predict the values
#         y_pred = model.predict(X)

#         # Calculate and store the R^2 value
#         r2_values[column] = r2_score(y, y_pred)

# # Convert the R^2 values dictionary to a DataFrame for better visualization
# r2_df = pd.DataFrame(list(r2_values.items()), columns=['Feature', 'R^2 Value']).sort_values(by='R^2 Value', ascending=False)

# r2_df
